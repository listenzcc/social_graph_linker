# %%
import random
import pandas as pd

# %%
departments = ['Organization', 'Police', 'Propagation', 'Military', 'Law', 'Industry']

def random_major(majors=departments):
    return random.choice(majors)

def random_name(region=None, k=None):
    if region is None:
        region = [chr(e) for e in range(ord('a'), ord('z')+1)]
    if k is None:
        k = [random.randint(3, 5), random.randint(5, 10)]
    xing = ''.join(random.choices(region, k=k[0])).title()
    ming = ''.join(random.choices(region, k=k[1])).title()
    return ' '.join([xing, ming])

def random_age(low=40, high=75):
    return random.randint(low, high)

def level3_uid(idx):
    return 'L3-{idx:04d}'.format(idx=idx)

# %%
num_level3 = 100

# %%
level3_df = pd.DataFrame(columns=['name', 'major', 'age', 'uid'])
level3_df
# Out:
# Empty DataFrame
# Columns: [name, major, age, uid]
# Index: []

# %%
for _ in range(num_level3):
    uid = level3_uid(_)
    info = dict(
        major = random_major(),
        name = random_name(),
        age = random_age(),
        uid = uid
    )
    level3_df = level3_df.append(pd.Series(info, name=uid))
level3_df
# Out:
#                    name         major age      uid
# L3-0000   Nlqpt Obpmxxm  Organization  40  L3-0000
# L3-0001       Gqm Dfwaa      Military  66  L3-0001
# L3-0002      Sor Zgpwfi      Industry  51  L3-0002
# L3-0003  Hpjk Ufldoqjnp        Police  60  L3-0003
# L3-0004      Mzq Vqbnoy           Law  42  L3-0004
# ...                 ...           ...  ..      ...
# L3-0095  Oato Zygftfpoe      Military  42  L3-0095
# L3-0096       Rpg Swmhe      Industry  69  L3-0096
# L3-0097     Spo Eltkrcq        Police  58  L3-0097
# L3-0098   Xyv Dbuukxfgk   Propagation  60  L3-0098
# L3-0099   Jxxjc Ljskqly           Law  75  L3-0099
#
# [100 rows x 4 columns]

# %%
level3_df.loc[level3_df['major'] == 'Industry']
# Out:
#                      name     major age      uid
# L3-0002        Sor Zgpwfi  Industry  51  L3-0002
# L3-0011  Lxzmz Yxzijbiiqd  Industry  43  L3-0011
# L3-0032   Hnsh Lcaavnyjzm  Industry  63  L3-0032
# L3-0051       Riq Tyadzkt  Industry  48  L3-0051
# L3-0058   Qtjbl Gxuxmnhjt  Industry  69  L3-0058
# L3-0059       Iqquf Rqeyk  Industry  52  L3-0059
# L3-0063     Gxiqv Jmmhybi  Industry  55  L3-0063
# L3-0069      Yzuel Bfevgp  Industry  62  L3-0069
# L3-0075     Wvf Dbpmfunqg  Industry  73  L3-0075
# L3-0076      Bgd Gvxbvsph  Industry  72  L3-0076
# L3-0084      Cvx Xznaialb  Industry  61  L3-0084
# L3-0086   Hmpth Ctwcismzu  Industry  62  L3-0086
# L3-0091     App Ylnnxoczw  Industry  62  L3-0091
# L3-0096         Rpg Swmhe  Industry  69  L3-0096

# %%
level3_df.loc[level3_df['age'].isin(range(55, 60))]
# Out:
#                     name         major age      uid
# L3-0012       Nsn Fohkdm      Military  59  L3-0012
# L3-0021     Aeh Orposfla  Organization  59  L3-0021
# L3-0030  Eivna Wnbnvtqha   Propagation  55  L3-0030
# L3-0034      Xmnsu Cbdno   Propagation  56  L3-0034
# L3-0041   Opjyg Blisvcik   Propagation  57  L3-0041
# L3-0045  Hiblu Zrkbjabpq      Military  58  L3-0045
# L3-0047    Yjy Pssvhzdhq  Organization  58  L3-0047
# L3-0055        Opv Rbibv   Propagation  57  L3-0055
# L3-0063    Gxiqv Jmmhybi      Industry  55  L3-0063
# L3-0077      Ohzl Ufqzrq           Law  57  L3-0077
# L3-0079  Ikpww Dnzzslroq           Law  56  L3-0079
# L3-0082    Smrar Jjgksvj   Propagation  57  L3-0082
# L3-0097      Spo Eltkrcq        Police  58  L3-0097

# %%
level3_df.to_json('level3.json')  # , orient='records')
